# %% [markdown]
# # Input Data

# %% [markdown]
# ##### The input email data is generated using Google's Gemini API. To make the use case realistic, emails of different categories are generated. The categories include:
# - Refund & Return Requests
# - Account, Billing & Subscription Inquiries
# - Shipping & Order Status
# - Mixed / Complex Scenarios
#
# Number of sample emails : 50

# %%
import pandas as pd 
df = pd.read_csv("data_inputs/emails.csv")
display(df.head())
# Out:
#    id                               subject  \
# 0   1  Trouble connecting my new headphones
# 1   2           Error code 404 during setup
# 2   3       Watch battery draining too fast
# 3   4  Coffee machine making strange noises
# 4   5               Hub not finding devices
#
#                                                 body
# 0  Hi Support,\nI bought the SonicBoom Wireless H...
# 1  Hello,\nI am trying to install the Vector Grap...
# 2  To whom it may concern,\nI’ve noticed that my ...
# 3  Hi there,\nMy BaristaPro Espresso Maker starte...
# 4  Good morning,\nI recently upgraded my router, ...

# %% [markdown]
# Sample Email

# %%
print(f"**Subject**:\n{df.iloc[0].subject}*\n\n**Body**:\n{df.iloc[0].body}")
# Out:
# **Subject**:
# Trouble connecting my new headphones*
#
# **Body**:
# Hi Support,
# I bought the SonicBoom Wireless Headphones last Tuesday, and I’m having a really hard time keeping them connected to my phone. They pair fine initially, but after about 10 minutes, the audio cuts out completely. I’ve tried resetting them and forgetting the device on my iPhone, but the issue persists. Can someone help me troubleshoot this? I need them for my commute.
# Best regards,
# Jason Miller

# %% [markdown]
# ### Extracting structured information with LLM

# %% [markdown]
# - We will use a LLM based approach to extract structured information from the sample emails
# - To do so, we first define a structured output in which we expect the LLM to extract the information

# %% [markdown]
# Few Questions :
# 1. What information can be extracted without using an LLM in a realistic scenario?
# - We can extract metadata like sender name and email, email time from the email address
# 2. Is intent a fixed category (Are there any fixed possible number of possible intents)
# - For the sake of simplicity lets assume that intent is not limited to a fixed category. Which means we can have any different types of intents. In a realistic scenario, we should have a limited set of intents to which all incidents map, and all unmappable should be in others category
# 3. If a particular information is not extractable in the email, what should we do about it?
# - To avoid false information and avoid LLM's hallucination we will let the LLM return None for anything it cannot understand
# 4. What are the mandatory fields?
# - Intent and the product information is required to understand the request
# - Some customers might not mention their name in the email hence customer name can be optional
# - Requested action can also be missing as the customer might need some help in finding the resolution

# %% [markdown]
# ### RequestAttributes Fields
#
# | Field Name         | Description                                                                                       | Mandatory       |
# |--------------------|---------------------------------------------------------------------------------------------------|-----------------|
# | **intent**          | Nature of the request (e.g., refund, replacement).                                                | Yes             |
# | **customer_name**   | Name of the customer. Use `None` if not mentioned.                                                | No              |
# | **product**         | Name of the product (e.g., Bluetooth speaker, mixer grinder).                                     | Yes             |
# | **requested_action**| Customer's desired action (e.g., refund, replacement). Use `None` if there isn’t enough information.| No              |

# %%
from groq_utils import RequestAttributes,get_email_attributes, email_structure

# %%
test_data = df.iloc[0]
test_input = email_structure.format(subject=test_data.subject,
                       body=test_data.body)

# %%
test_output = await get_email_attributes(test_input)

# %% [markdown]
# # Now lets run this for all the sample emails in the dataframe

# %% [markdown]
# To run this over the data we have
# - we will make asynchronous calls to the LLMs as the data is big and it is not a good practices to synchronously loop over this
# - once we have run it for all the data we will create additional columns to the dataframe
# - at last we will save the dataframe as output

# %%
email_dataset = df.apply(lambda x: email_structure.format(subject=x.subject,body = x.body),axis=1).to_list()

# %%
from typing import List
import asyncio
async def run_for_all_examples(list_of_email:List[str]):
    results = await asyncio.gather(*(get_email_attributes(email_item) for email_item in email_dataset))
    return results

# %%
results = await run_for_all_examples(email_dataset)
# Out:
# Request failed for:  etro Red" colorway, size 11. Your website says "Out of Stock," but I was wondering if you have any inventory in your physical warehouse that isn't listed online? Or do you know when you will restock?
# Michael Jordan
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `openai/gpt-oss-120b` in organization `org_01jafq4jnfep6r02ahnt3y1m95` service tier `on_demand` on tokens per minute (TPM): Limit 8000, Used 7843, Requested 390. Please try again in 1.7475s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Request failed for:  ing Gown. I selected standard shipping, but I just found out I need it for an event this Friday. Is it possible to pay the difference to upgrade to Overnight or 2-Day shipping? Please let me know ASAP so it doesn't ship standard.
# Rachel Green
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `openai/gpt-oss-120b` in organization `org_01jafq4jnfep6r02ahnt3y1m95` service tier `on_demand` on tokens per minute (TPM): Limit 8000, Used 7843, Requested 394. Please try again in 1.777499999s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Request failed for:  itself, but it stopped syncing with the Strava app on my phone about three days ago. I tried unlinking and relinking the accounts, but it says "Sync Error." Any ideas?
# Steve Austin
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `openai/gpt-oss-120b` in organization `org_01jafq4jnfep6r02ahnt3y1m95` service tier `on_demand` on tokens per minute (TPM): Limit 8000, Used 7843, Requested 385. Please try again in 1.71s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Request failed for:  nking App on a new phone. It asks for a 2-factor authentication code via SMS, but I have been waiting for 20 minutes and haven't received anything. My phone number hasn't changed. Can we try verifying via email instead?
# James Bond
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `openai/gpt-oss-120b` in organization `org_01jafq4jnfep6r02ahnt3y1m95` service tier `on_demand` on tokens per minute (TPM): Limit 8000, Used 7842, Requested 393. Please try again in 1.7625s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Request failed for:  o custom orders? I want one that says "Saul's Office" in yellow and blue. Let me know the lead time and pricing for custom work.
# Saul Goodman
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `openai/gpt-oss-120b` in organization `org_01jafq4jnfep6r02ahnt3y1m95` service tier `on_demand` on tokens per minute (TPM): Limit 8000, Used 7842, Requested 379. Please try again in 1.6575s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Request failed for:  t an email confirming you received the return on the 10th. It is now the 24th and I still haven't seen the credit appear on my Visa card. How long does this usually take?
# Clark Griswold
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `openai/gpt-oss-120b` in organization `org_01jafq4jnfep6r02ahnt3y1m95` service tier `on_demand` on tokens per minute (TPM): Limit 8000, Used 7842, Requested 389. Please try again in 1.7325s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Request failed for:  for my VisionX 55" Smart TV. Do you sell replacement remotes separately? I can't find one on your website.
# Clark Kent
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `openai/gpt-oss-120b` in organization `org_01jafq4jnfep6r02ahnt3y1m95` service tier `on_demand` on tokens per minute (TPM): Limit 8000, Used 7842, Requested 370. Please try again in 1.589999999s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Request failed for:   I want to buy the DesignPro Software license, but the full price is a bit out of my budget. Do you offer an educational discount for students with a valid .edu email address?
# Miles Morales
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `openai/gpt-oss-120b` in organization `org_01jafq4jnfep6r02ahnt3y1m95` service tier `on_demand` on tokens per minute (TPM): Limit 8000, Used 7841, Requested 378. Please try again in 1.6425s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Request failed for:  with the app immediately, but the fourth one just blinks rapidly and won't connect no matter what I do. I think this specific bulb is a dud. How do I get a replacement for just the one bulb?
# Thomas Edison
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `openai/gpt-oss-120b` in organization `org_01jafq4jnfep6r02ahnt3y1m95` service tier `on_demand` on tokens per minute (TPM): Limit 8000, Used 7841, Requested 393. Please try again in 1.755s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Request failed for:   of washing my driveway. I bought it 11 months ago, so it should still be under the 1-year warranty. How do I initiate a warranty claim for a repair or replacement?
# Thor Odinson
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `openai/gpt-oss-120b` in organization `org_01jafq4jnfep6r02ahnt3y1m95` service tier `on_demand` on tokens per minute (TPM): Limit 8000, Used 7840, Requested 382. Please try again in 1.665s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Request failed for:  use I forgot mine once and started a new one. Is there a way to combine the points from card #1234 and card #5678 onto a single account? I want to redeem my free drink.
# Lorelai Gilmore
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `openai/gpt-oss-120b` in organization `org_01jafq4jnfep6r02ahnt3y1m95` service tier `on_demand` on tokens per minute (TPM): Limit 8000, Used 7840, Requested 388. Please try again in 1.71s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Request failed for:   a wire labeled "K" but your manual doesn't mention where a K-wire goes. I don't want to short out my HVAC system. Can you send me a wiring diagram for a system with a K-wire?
# Frodo Baggins
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `openai/gpt-oss-120b` in organization `org_01jafq4jnfep6r02ahnt3y1m95` service tier `on_demand` on tokens per minute (TPM): Limit 8000, Used 7839, Requested 394. Please try again in 1.7475s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Request failed for:  de, but the set of Resistance Bands that I ordered in the same transaction is missing. The packing slip lists both items. Are the bands coming in a separate box?
# Lara Croft
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `openai/gpt-oss-120b` in organization `org_01jafq4jnfep6r02ahnt3y1m95` service tier `on_demand` on tokens per minute (TPM): Limit 8000, Used 7840, Requested 380. Please try again in 1.65s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Request failed for:   of $4.99 from your company labeled "Service Fee." I never agreed to this. I only bought the product, I didn't sign up for any service. Please explain this charge or refund it immediately.
# Scrooge McDuck
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `openai/gpt-oss-120b` in organization `org_01jafq4jnfep6r02ahnt3y1m95` service tier `on_demand` on tokens per minute (TPM): Limit 8000, Used 7840, Requested 390. Please try again in 1.725s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Request failed for:  ame on my account without my permission. We have not downloaded or played it yet. Can you please reverse this transaction and refund the $59.99 to my card?
# Thank you,
# Linda Wei
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `openai/gpt-oss-120b` in organization `org_01jafq4jnfep6r02ahnt3y1m95` service tier `on_demand` on tokens per minute (TPM): Limit 8000, Used 7840, Requested 377. Please try again in 1.6275s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Request failed for:  n of my account and all associated personal data from the SocialConnect platform, in accordance with GDPR regulations. Please confirm once my data has been permanently removed from your servers.
# Hermione Granger
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `openai/gpt-oss-120b` in organization `org_01jafq4jnfep6r02ahnt3y1m95` service tier `on_demand` on tokens per minute (TPM): Limit 8000, Used 7839, Requested 379. Please try again in 1.635s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Request failed for:  ool trip, but the website description doesn't explicitly say if they are produced in a nut-free facility. He has a severe peanut allergy. Can you confirm if there is cross-contamination risk?
# Charlie Bucket
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `openai/gpt-oss-120b` in organization `org_01jafq4jnfep6r02ahnt3y1m95` service tier `on_demand` on tokens per minute (TPM): Limit 8000, Used 7840, Requested 383. Please try again in 1.6725s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Request failed for:  rtunately, the cap was loose and about half the bottle leaked out inside the bubble wrap. It’s a sticky mess. Can you send a replacement bottle? I can send photos of the packaging.
# Daenerys Targaryen
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `openai/gpt-oss-120b` in organization `org_01jafq4jnfep6r02ahnt3y1m95` service tier `on_demand` on tokens per minute (TPM): Limit 8000, Used 7839, Requested 389. Please try again in 1.71s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Request failed for:  I already have one. I don't have the original receipt, just the gift receipt. Can I return this for store credit instead of a refund to the purchaser's card?
# Harry Potter
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `openai/gpt-oss-120b` in organization `org_01jafq4jnfep6r02ahnt3y1m95` service tier `on_demand` on tokens per minute (TPM): Limit 8000, Used 7836, Requested 383. Please try again in 1.6425s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Request failed for:  e settings, but it says my account is locked. I tried the "forgot password" link, but I never received the email. Can someone please help me regain access? I have important files I need to get to.
# Fatima Al-Fayed
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `openai/gpt-oss-120b` in organization `org_01jafq4jnfep6r02ahnt3y1m95` service tier `on_demand` on tokens per minute (TPM): Limit 8000, Used 7836, Requested 393. Please try again in 1.7175s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Request failed for:  aw a visible spark at the wall outlet and smelled burning plastic. I unplugged it immediately. This seems dangerous. How do I return this safely?
# Clint Barton
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `openai/gpt-oss-120b` in organization `org_01jafq4jnfep6r02ahnt3y1m95` service tier `on_demand` on tokens per minute (TPM): Limit 8000, Used 7836, Requested 377. Please try again in 1.5975s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Request failed for:  kshelf I bought. Step 3 requires 'Screw Type B', but the bag is completely empty. I can't finish building this without them. Can you ship a hardware pack to me?
# Bob the Builder
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `openai/gpt-oss-120b` in organization `org_01jafq4jnfep6r02ahnt3y1m95` service tier `on_demand` on tokens per minute (TPM): Limit 8000, Used 7836, Requested 382. Please try again in 1.635s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Request failed for:  r platform. The event organizers just announced it's cancelled due to weather. Will the refund for my tickets happen automatically, or do I need to file a claim form?
# Jimi Hendrix
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `openai/gpt-oss-120b` in organization `org_01jafq4jnfep6r02ahnt3y1m95` service tier `on_demand` on tokens per minute (TPM): Limit 8000, Used 7834, Requested 376. Please try again in 1.575s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Request failed for:  iced two pending charges of $49.99 for my subscription to MealPlan Plus. I only authorized one month. Please refund the duplicate charge immediately and confirm that my auto-renew is actually off.
# Robert Downey
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `openai/gpt-oss-120b` in organization `org_01jafq4jnfep6r02ahnt3y1m95` service tier `on_demand` on tokens per minute (TPM): Limit 8000, Used 7834, Requested 385. Please try again in 1.6425s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Request failed for:  on to CloudSync Premium has been renewed for another year ($120). I meant to cancel this before the trial ended yesterday but forgot. I haven't uploaded any files since I signed up. Is it possible to cancel this now and get a refund on the renewal fee?
# John Wick
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `openai/gpt-oss-120b` in organization `org_01jafq4jnfep6r02ahnt3y1m95` service tier `on_demand` on tokens per minute (TPM): Limit 8000, Used 7833, Requested 396. Please try again in 1.7175s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Request failed for:  reamMusic Unlimited. I want to upgrade to the Family Plan so my kids can use it too. How do I do this without losing my current playlists?
# Angela Rossi
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `openai/gpt-oss-120b` in organization `org_01jafq4jnfep6r02ahnt3y1m95` service tier `on_demand` on tokens per minute (TPM): Limit 8000, Used 7831, Requested 374. Please try again in 1.537499999s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Request failed for:  ption has expired. I tried to update it in the portal, but the 'Save' button is greyed out. I don't want to miss this month's shipment. Can someone help me update my card manually?
# Tyrion Lannister
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `openai/gpt-oss-120b` in organization `org_01jafq4jnfep6r02ahnt3y1m95` service tier `on_demand` on tokens per minute (TPM): Limit 8000, Used 7832, Requested 388. Please try again in 1.65s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Request failed for:  unt is currently linked to my work email (lois@dailyplanet.com). I need to change it to my personal email so I don't lose access to my purchase history.
# Lois Lane
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `openai/gpt-oss-120b` in organization `org_01jafq4jnfep6r02ahnt3y1m95` service tier `on_demand` on tokens per minute (TPM): Limit 8000, Used 7832, Requested 381. Please try again in 1.5975s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Request failed for:   for the purchase of the ErgoOffice Desk Chair? I bought it last week, but I can't find the receipt in my email. I need it to submit an expense report to my company.
# Samantha Lee
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `openai/gpt-oss-120b` in organization `org_01jafq4jnfep6r02ahnt3y1m95` service tier `on_demand` on tokens per minute (TPM): Limit 8000, Used 7830, Requested 382. Please try again in 1.589999999s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Request failed for:   said it would ship by the 15th, but my status still says "Processing." Can you give me an update on when this is actually going to be sent out?
# Bruce Wayne
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `openai/gpt-oss-120b` in organization `org_01jafq4jnfep6r02ahnt3y1m95` service tier `on_demand` on tokens per minute (TPM): Limit 8000, Used 7829, Requested 383. Please try again in 1.589999999s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Request failed for:  or our small office last week. We managed to get it working via USB, but the wireless feature is failing. It finds the network, asks for the password, and then just spins until it times out. We have a standard WPA2 setup. Can someone guide us through the network configuration? We need this wireless for our mobile devices.
# Thanks,
# Sarah Connor
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `openai/gpt-oss-120b` in organization `org_01jafq4jnfep6r02ahnt3y1m95` service tier `on_demand` on tokens per minute (TPM): Limit 8000, Used 7829, Requested 414. Please try again in 1.8225s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Request failed for:  dphones last Tuesday, and I’m having a really hard time keeping them connected to my phone. They pair fine initially, but after about 10 minutes, the audio cuts out completely. I’ve tried resetting them and forgetting the device on my iPhone, but the issue persists. Can someone help me troubleshoot this? I need them for my commute.
# Best regards,
# Jason Miller
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `openai/gpt-oss-120b` in organization `org_01jafq4jnfep6r02ahnt3y1m95` service tier `on_demand` on tokens per minute (TPM): Limit 8000, Used 7825, Requested 415. Please try again in 1.799999999s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Request failed for:   The bed frame arrived via freight yesterday, but the Memory Foam Mattress was not on the truck. The driver said he only had one box for me. When can I expect the mattress? I can't really use the bed without it.
# Sleeping Beauty
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `openai/gpt-oss-120b` in organization `org_01jafq4jnfep6r02ahnt3y1m95` service tier `on_demand` on tokens per minute (TPM): Limit 8000, Used 7825, Requested 391. Please try again in 1.62s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Request failed for:  th the delivery of my GroceryFresh Order. The driver left the bags in the middle of the driveway in the rain, instead of on the covered porch. Half my paper bags soaked through and ripped. I expect a refund for the damaged items.
# Karen Page
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `openai/gpt-oss-120b` in organization `org_01jafq4jnfep6r02ahnt3y1m95` service tier `on_demand` on tokens per minute (TPM): Limit 8000, Used 7825, Requested 390. Please try again in 1.6125s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Request failed for:  s immediately upon opening. I can't access my funds. I've tried reinstalling the app and restarting my phone, but nothing works. Please fix this bug ASAP.
# Satoshi Nakamoto
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `openai/gpt-oss-120b` in organization `org_01jafq4jnfep6r02ahnt3y1m95` service tier `on_demand` on tokens per minute (TPM): Limit 8000, Used 7825, Requested 379. Please try again in 1.529999999s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Request failed for:  ery time I try to load the second mission, the game freezes and crashes to the desktop without an error message. My drivers are up to date. Is there a patch coming for this? I can't progress in the game.
# Luke Skywalker
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `openai/gpt-oss-120b` in organization `org_01jafq4jnfep6r02ahnt3y1m95` service tier `on_demand` on tokens per minute (TPM): Limit 8000, Used 7824, Requested 389. Please try again in 1.5975s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Request failed for:   night. The chicken included in the kit smelled awful and was clearly spoiled. We had to throw the whole dinner out and order pizza. I am extremely unhappy with the quality control. I want a full refund.
# Gordon Ramsay
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `openai/gpt-oss-120b` in organization `org_01jafq4jnfep6r02ahnt3y1m95` service tier `on_demand` on tokens per minute (TPM): Limit 8000, Used 7824, Requested 389. Please try again in 1.5975s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# Request failed for:  buy a Gift Card on your site. I did not make this purchase! Please cancel this immediately and refund my card.
# Wanda Maximoff
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `openai/gpt-oss-120b` in organization `org_01jafq4jnfep6r02ahnt3y1m95` service tier `on_demand` on tokens per minute (TPM): Limit 8000, Used 7823, Requested 369. Please try again in 1.44s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}

# %% [markdown]
# ### In the above sample we see that we are facing rate limit exceeded error, so we will have to handle rate limits gracefully

# %% [markdown]
# To handle this we will do the following things:
# - Limit the execution of the tasks to only a few workers (To prevent concurrent request error)
# - Induce a small sleep timer after each request to prevent (To prevent request per minute error)

# %%
from typing import List
import asyncio
async def worker(item, sem):
    async with sem:          # acquire semaphore
        await asyncio.sleep(0.2) # we will create a small sleep time
        return await get_email_attributes(item)  # actual work
    
async def run_for_all_examples(list_of_email:List[str]):
    sem = asyncio.Semaphore(2)   # allow max 2 tasks at a time
    tasks = [worker(email_item, sem) for email_item in email_dataset]
    results = await asyncio.gather(*tasks)
    return results

# %%
results = await run_for_all_examples(email_dataset)

# %%
# Finally populate the dataframe from all the values
for attribute in RequestAttributes.model_fields.keys():
    df[attribute] = [i.get(attribute,"") for i in results]

# %%
# saving the dataframe
df.to_csv("data_output/results.csv",index=False)

# %%
df
# Out:
#     id                                 subject  \
# 0    1    Trouble connecting my new headphones
# 1    2             Error code 404 during setup
# 2    3         Watch battery draining too fast
# 3    4    Coffee machine making strange noises
# 4    5                 Hub not finding devices
# 5    6            Display issues on new laptop
# 6    7               Broken screen in shipment
# 7    8                You sent the wrong color
# 8    9                    Returning the vacuum
# 9   10                Cancel and refund please
# 10  11                     Boots falling apart
# 11  12                        Arrived too late
# 12  13        Charged twice for the same order
# 13  14                Locked out of my account
# 14  15                    Stop my subscription
# 15  16           Need receipt for tax purposes
# 16  17                 Update shipping address
# 17  18            Upgrading to the family plan
# 18  19  Tracking says delivered but no package
# 19  20             Missing items from my order
# 20  21                      When will it ship?
# 21  22             Will this work with my Mac?
# 22  23                   Discount didn't apply
# 23  24             Feature request for the app
# 24  25                   Motor stopped working
# 25  26                     I have two accounts
# 26  27                         Lost the remote
# 27  28                Unauthorized transaction
# 28  29            adding installation to order
# 29  30                           Sparking plug
# 30  31   Printer refuses to connect to network
# 31  32             Question about bulk pricing
# 32  33    Subscription auto-renewed by mistake
# 33  34                     Wrong size received
# 34  35                   2FA code not arriving
# 35  36             Incomplete shipment inquiry
# 36  37             Data export feature request
# 37  38                         Leaking product
# 38  39             Game keeps crashing on load
# 39  40               Need to expedite shipping
# 40  41                GDPR - Delete my account
# 41  42                   Customization inquiry
# 42  43                 Sync failed with Strava
# 43  44              Allergy information needed
# 44  45                   Update payment method
# 45  46         Complaint about delivery driver
# 46  47                   Smart bulb won't pair
# 47  48            Educational discount inquiry
# 48  49                  Merging loyalty points
# 49  50              Refund for cancelled event
# 50  51              Drone drifting to the left
# 51  52                Unknown fee on statement
# 52  53                        Returning a gift
# 53  54                Stock availability check
# 54  55                  Thermostat wiring help
# 55  56                    Change email address
# 56  57                      Food quality issue
# 57  58                  App crashes on startup
# 58  59             Missing screws for assembly
# 59  60                     Where is my refund?
#
#                                                  body  \
# 0   Hi Support,\nI bought the SonicBoom Wireless H...
# 1   Hello,\nI am trying to install the Vector Grap...
# 2   To whom it may concern,\nI’ve noticed that my ...
# 3   Hi there,\nMy BaristaPro Espresso Maker starte...
# 4   Good morning,\nI recently upgraded my router, ...
# 5   Hi Team,\nI received my Titan Gaming Laptop X1...
# 6   Hello,\nI am extremely disappointed. I just op...
# 7   Hi,\nI ordered the Velvet Armchair in Navy Blu...
# 8   Hi Customer Service,\nI would like to request ...
# 9   Hello,\nMy son accidentally purchased the Gala...
# 10  Hi,\nI bought a pair of TrailBlazer Hiking Boo...
# 11  To the support team,\nI ordered the PartyBox B...
# 12  Hi,\nI was checking my credit card statement a...
# 13  Hello,\nI am trying to log in to manage my Clo...
# 14  Hi,\nPlease cancel my subscription to FitLife ...
# 15  Good afternoon,\nCould you please send me a PD...
# 16  Hi,\nI just placed an order for the InstaPot D...
# 17  Hello Team,\nI currently have the individual p...
# 18  Hi,\nI have a problem. The tracking number for...
# 19  Hello,\nI received my package today. The Yoga ...
# 20  Hi,\nI pre-ordered the NextGen Console two mon...
# 21  Hi,\nI am looking at buying the External SSD 2...
# 22  Hello,\nI just bought the Winter Down Jacket a...
# 23  Hi Team,\nI love using the TaskMaster Project ...
# 24  To Support,\nMy HydroClean Power Washer just d...
# 25  Hi,\nI realized I have two accounts for Reader...
# 26  Hello,\nWe moved recently and I seem to have l...
# 27  Urgent,\nI just got a notification that my car...
# 28  Hi,\nI ordered the HeavyDuty Washing Machine y...
# 29  URGENT:\nI plugged in my HeatWave Space Heater...
# 30  Hi Support,\nI purchased the PrintMaster 5000 ...
# 31  Good morning,\nI am looking to outfit our enti...
# 32  Hello,\nI just got an email saying my subscrip...
# 33  Hi,\nI ordered the Vintage Denim Jacket in a s...
# 34  To Security Support,\nI am trying to log into ...
# 35  Hello,\nI ordered the Bedroom makeover set (Or...
# 36  Hi,\nI've been using FinanceTracker 360 for my...
# 37  Hi,\nI received my order for the GlowSkin Vita...
# 38  Support,\nI bought Starship Commander on PC ye...
# 39  Hi there,\nI placed an order this morning for ...
# 40  To the Privacy Officer,\nI am writing to reque...
# 41  Hello,\nI see you sell the Neon Bar Sign on yo...
# 42  Hi,\nMy FitnessBand X is tracking my steps fin...
# 43  Hi,\nI want to buy the Nutty Granola Bars for ...
# 44  Hello,\nMy credit card on file for the Monthly...
# 45  To Customer Service,\nI need to report an inci...
# 46  Hi,\nI bought a 4-pack of LumaHome Bulbs. Thre...
# 47  Hello,\nI am a university student studying arc...
# 48  Hi,\nI have two loyalty cards for the Morning ...
# 49  Hi,\nI bought tickets for the Summer Rock Fest...
# 50  Support,\nMy SkyEye Drone has a serious calibr...
# 51  Hello,\nI am looking at my bank statement and ...
# 52  Hi,\nI received the TurboShaver 3000 as a gift...
# 53  Hi,\nI've been trying to find the AirJump Snea...
# 54  Hello,\nI am trying to install the ThermoSmart...
# 55  Hi,\nI need to update my profile. I am changin...
# 56  To Whom It May Concern,\nWe ordered the Family...
# 57  Hi,\nSince the last update on iOS, the CryptoW...
# 58  Hi,\nI am currently trying to put together the...
# 59  Hello,\nI returned the NoiseCancel Headphones ...
#
#                                         email_content  \
# 0   Subject: Error code 404 during setup \n Body:H...
# 1   Subject: Error code 404 during setup \n Body:H...
# 2   Subject: Error code 404 during setup \n Body:H...
# 3   Subject: Error code 404 during setup \n Body:H...
# 4   Subject: Error code 404 during setup \n Body:H...
# 5   Subject: Error code 404 during setup \n Body:H...
# 6   Subject: Error code 404 during setup \n Body:H...
# 7   Subject: Error code 404 during setup \n Body:H...
# 8   Subject: Error code 404 during setup \n Body:H...
# 9   Subject: Error code 404 during setup \n Body:H...
# 10  Subject: Error code 404 during setup \n Body:H...
# 11  Subject: Error code 404 during setup \n Body:H...
# 12  Subject: Error code 404 during setup \n Body:H...
# 13  Subject: Error code 404 during setup \n Body:H...
# 14  Subject: Error code 404 during setup \n Body:H...
# 15  Subject: Error code 404 during setup \n Body:H...
# 16  Subject: Error code 404 during setup \n Body:H...
# 17  Subject: Error code 404 during setup \n Body:H...
# 18  Subject: Error code 404 during setup \n Body:H...
# 19  Subject: Error code 404 during setup \n Body:H...
# 20  Subject: Error code 404 during setup \n Body:H...
# 21  Subject: Error code 404 during setup \n Body:H...
# 22  Subject: Error code 404 during setup \n Body:H...
# 23  Subject: Error code 404 during setup \n Body:H...
# 24  Subject: Error code 404 during setup \n Body:H...
# 25  Subject: Error code 404 during setup \n Body:H...
# 26  Subject: Error code 404 during setup \n Body:H...
# 27  Subject: Error code 404 during setup \n Body:H...
# 28  Subject: Error code 404 during setup \n Body:H...
# 29  Subject: Error code 404 during setup \n Body:H...
# 30  Subject: Error code 404 during setup \n Body:H...
# 31  Subject: Error code 404 during setup \n Body:H...
# 32  Subject: Error code 404 during setup \n Body:H...
# 33  Subject: Error code 404 during setup \n Body:H...
# 34  Subject: Error code 404 during setup \n Body:H...
# 35  Subject: Error code 404 during setup \n Body:H...
# 36  Subject: Error code 404 during setup \n Body:H...
# 37  Subject: Error code 404 during setup \n Body:H...
# 38  Subject: Error code 404 during setup \n Body:H...
# 39  Subject: Error code 404 during setup \n Body:H...
# 40  Subject: Error code 404 during setup \n Body:H...
# 41  Subject: Error code 404 during setup \n Body:H...
# 42  Subject: Error code 404 during setup \n Body:H...
# 43  Subject: Error code 404 during setup \n Body:H...
# 44  Subject: Error code 404 during setup \n Body:H...
# 45  Subject: Error code 404 during setup \n Body:H...
# 46  Subject: Error code 404 during setup \n Body:H...
# 47  Subject: Error code 404 during setup \n Body:H...
# 48  Subject: Error code 404 during setup \n Body:H...
# 49  Subject: Error code 404 during setup \n Body:H...
# 50  Subject: Error code 404 during setup \n Body:H...
# 51  Subject: Error code 404 during setup \n Body:H...
# 52  Subject: Error code 404 during setup \n Body:H...
# 53  Subject: Error code 404 during setup \n Body:H...
# 54  Subject: Error code 404 during setup \n Body:H...
# 55  Subject: Error code 404 during setup \n Body:H...
# 56  Subject: Error code 404 during setup \n Body:H...
# 57  Subject: Error code 404 during setup \n Body:H...
# 58  Subject: Error code 404 during setup \n Body:H...
# 59  Subject: Error code 404 during setup \n Body:H...
#
#                                   intent       customer_name  \
# 0              troubleshoot connectivity        Jason Miller
# 1                     installation_error       Sarah Jenkins
# 2              battery performance issue          Amit Patel
# 3                      technical support     Elena Rodriguez
# 4                     connectivity issue       Michael Chang
# 5                          display issue       Jessica Bloom
# 6                                 damage        David Thorne
# 7                            wrong color         Priya Singh
# 8                                 refund          Tom Hansen
# 9                                 refund           Linda Wei
# 10                                refund      Marcus Johnson
# 11                                refund         Chloe Evans
# 12                                refund       Robert Downey
# 13
# 14                   cancel subscription         Greg Norman
# 15                       request receipt        Samantha Lee
# 16                        address change      Kevin O'Connor
# 17                          plan upgrade        Angela Rossi
# 18                        delivery issue        Peter Parker
# 19                         missing items          Lara Croft
# 20               shipping status inquiry         Bruce Wayne
# 21                 compatibility inquiry        Steve Rogers
# 22                  discount not applied    Natasha Romanoff
# 23                       feature request          Tony Stark
# 24                        warranty claim        Thor Odinson
# 25                         account merge        Diana Prince
# 26                           replacement          Clark Kent
# 27              unauthorized transaction      Wanda Maximoff
# 28              add installation service        Bucky Barnes
# 29                        safety concern        Clint Barton
# 30  troubleshooting network connectivity        Sarah Connor
# 31                       pricing inquiry      Dwight Schrute
# 32                                refund           John Wick
# 33                              exchange         Marty McFly
# 34                 2FA code not received          James Bond
# 35                   incomplete shipment     Sleeping Beauty
# 36                       feature request        Gordon Gekko
# 37                        leak complaint  Daenerys Targaryen
# 38                       technical issue      Luke Skywalker
# 39                      shipping upgrade        Rachel Green
# 40                      account deletion    Hermione Granger
# 41                 customization inquiry        Saul Goodman
# 42                            sync issue        Steve Austin
# 43                       product inquiry      Charlie Bucket
# 44                 update payment method    Tyrion Lannister
# 45                             complaint          Karen Page
# 46                           replacement       Thomas Edison
# 47          educational discount inquiry       Miles Morales
# 48                  merge loyalty points     Lorelai Gilmore
# 49                                refund        Jimi Hendrix
# 50                       technical issue   Maverick Mitchell
# 51                           fee dispute      Scrooge McDuck
# 52                                return        Harry Potter
# 53              stock availability check      Michael Jordan
# 54                     technical support       Frodo Baggins
# 55                  update account email           Lois Lane
# 56                                refund       Gordon Ramsay
# 57                       technical issue    Satoshi Nakamoto
# 58                         missing parts     Bob the Builder
# 59                                refund      Clark Griswold
#
#                           product  \
# 0   SonicBoom Wireless Headphones
# 1      Vector Graphics Suite 2024
# 2           Apex Smartwatch Gen 5
# 3       BaristaPro Espresso Maker
# 4          HomeGuard Security Hub
# 5         Titan Gaming Laptop X15
# 6            UltraView 4K Monitor
# 7                 Velvet Armchair
# 8            Cyclone Stick Vacuum
# 9           Galactic Raiders Game
# 10       TrailBlazer Hiking Boots
# 11     PartyBox Bluetooth Speaker
# 12                  MealPlan Plus
# 13
# 14                    FitLife Pro
# 15          ErgoOffice Desk Chair
# 16                   InstaPot Duo
# 17          StreamMusic Unlimited
# 18         SilentNight Humidifier
# 19               Resistance Bands
# 20                NextGen Console
# 21               External SSD 2TB
# 22             Winter Down Jacket
# 23        TaskMaster Project Tool
# 24        HydroClean Power Washer
# 25            ReaderDigest Online
# 26           VisionX 55" Smart TV
# 27                      Gift Card
# 28      HeavyDuty Washing Machine
# 29          HeatWave Space Heater
# 30               PrintMaster 5000
# 31       Ergonomic Wrist Rest Pro
# 32              CloudSync Premium
# 33           Vintage Denim Jacket
# 34        SecureVault Banking App
# 35           Bedroom makeover set
# 36             FinanceTracker 360
# 37       GlowSkin Vitamin C Serum
# 38             Starship Commander
# 39              Silk Evening Gown
# 40         SocialConnect platform
# 41                  Neon Bar Sign
# 42                  FitnessBand X
# 43             Nutty Granola Bars
# 44  Monthly Wine Box subscription
# 45                   GroceryFresh
# 46                 LumaHome Bulbs
# 47     DesignPro Software license
# 48            Morning Coffee Club
# 49   Summer Rock Festival tickets
# 50                   SkyEye Drone
# 51
# 52               TurboShaver 3000
# 53               AirJump Sneakers
# 54                 ThermoSmart V2
# 55                        account
# 56          Family Feast Meal Kit
# 57               CryptoWallet App
# 58               Nordic Bookshelf
# 59         NoiseCancel Headphones
#
#                                      requested_action
# 0                                        troubleshoot
# 1                           troubleshoot installation
# 2                           investigate battery issue
# 3                                          technician
# 4                                              assist
# 5                                              repair
# 6                          replacement or full refund
# 7                       return and send correct color
# 8                                              refund
# 9                                              refund
# 10                                             refund
# 11                                             refund
# 12                                             refund
# 13
# 14                                cancel subscription
# 15                                   send PDF invoice
# 16                            update shipping address
# 17                             upgrade to Family Plan
# 18                                       locate order
# 19                                  send missing item
# 20                            provide shipping update
# 21          confirm compatibility with macOS Monterey
# 22         adjust the price to apply the 20% discount
# 23                                      add dark mode
# 24  initiate a warranty claim for a repair or repl...
# 25                                     merge accounts
# 26                                        replacement
# 27                                  cancel and refund
# 28                      add professional installation
# 29                                             return
# 30       guide through wireless network configuration
# 31                    request quote for bulk discount
# 32     cancel subscription and refund the renewal fee
# 33                           exchange for Medium size
# 34                                   verify via email
# 35               deliver missing Memory Foam Mattress
# 36                       add data export to CSV/Excel
# 37                                        replacement
# 38                               provide patch or fix
# 39  upgrade to overnight or 2-day shipping by payi...
# 40                                     delete account
# 41  custom order request for personalized sign wit...
# 42                                 resolve sync error
# 43  confirm allergy information and cross-contamin...
# 44                          manual credit card update
# 45                                             refund
# 46                                        replacement
# 47             information about educational discount
# 48  combine points from card #1234 and card #5678 ...
# 49                                             refund
# 50                                             repair
# 51                                             refund
# 52                                       store credit
# 53   inquire about restock and inventory availability
# 54       send wiring diagram for system with a K-wire
# 55                               change email address
# 56                                             refund
# 57                                            fix bug
# 58                               ship a hardware pack
# 59                                             refund
